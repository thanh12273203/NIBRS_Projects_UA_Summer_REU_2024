# %%
# Import necessary dependencies
import sys
import os
import zipfile

import numpy as np
import pandas as pd
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns

# Get the current working directory
current_dir = os.getcwd()

# Project directory
project_dir = os.path.abspath(os.path.join(current_dir, '..', '..'))
sys.path.append(project_dir)

# Python file for custom functions
from src.utils import *

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Directory to your zipfile
ZIPFILE_PATH = os.path.join(project_dir, 'datasets', 'ICPSR_38925-V1.zip')

# Directories to the parquet files
DS0001 = os.path.join(project_dir, 'datasets', 'ICPSR_38925/batch_header_extract_ds0001.parquet')
DS0002 = os.path.join(project_dir, 'datasets', 'ICPSR_38925/admin_extract_ds0002.parquet')
DS0003 = os.path.join(project_dir, 'datasets', 'ICPSR_38925/incident_extract_ds0003.parquet')
DS0004 = os.path.join(project_dir, 'datasets', 'ICPSR_38925/victim_extract_ds0004.parquet')
DS0005 = os.path.join(project_dir, 'datasets', 'ICPSR_38925/arrestee_extract_ds0005.parquet')
DS0006 = os.path.join(project_dir, 'datasets', 'ICPSR_38925/offender_extract_ds0006.parquet')

# Directory to your codebook
CODEBOOK_PATH = os.path.join(project_dir, '38925-Documentation-PI_Codebook.xlsx')  # extracted
# CODEBOOK_PATH = 'ICPSR_38925-V1/ICPSR_38925/38925-Documentation-PI_Codebook.xlsx'  # in the zipfile

# %%
# Access to zip file
czip = zipfile.ZipFile(ZIPFILE_PATH)
czip.namelist()
# Out:
# ['ICPSR_38925-V1/',
#  'ICPSR_38925-V1/ICPSR_38925/',
#  'ICPSR_38925-V1/ICPSR_38925/38925-Documentation-PI_Codebook.xlsx',
#  'ICPSR_38925-V1/ICPSR_38925/DS0001/',
#  'ICPSR_38925-V1/ICPSR_38925/DS0001/38925-0001-Data.tsv',
#  'ICPSR_38925-V1/ICPSR_38925/DS0001/38925-0001-Codebook-ICPSR.pdf',
#  'ICPSR_38925-V1/ICPSR_38925/DS0002/',
#  'ICPSR_38925-V1/ICPSR_38925/DS0002/38925-0002-Codebook-ICPSR.pdf',
#  'ICPSR_38925-V1/ICPSR_38925/DS0002/38925-0002-Data.tsv',
#  'ICPSR_38925-V1/ICPSR_38925/DS0003/',
#  'ICPSR_38925-V1/ICPSR_38925/DS0003/38925-0003-Data.tsv',
#  'ICPSR_38925-V1/ICPSR_38925/DS0003/38925-0003-Documentation-readme_gzip.txt',
#  'ICPSR_38925-V1/ICPSR_38925/DS0003/38925-0003-Codebook-ICPSR.pdf',
#  'ICPSR_38925-V1/ICPSR_38925/38925-related_literature.txt',
#  'ICPSR_38925-V1/ICPSR_38925/38925-manifest.txt',
#  'ICPSR_38925-V1/ICPSR_38925/38925-descriptioncitation.html',
#  'ICPSR_38925-V1/ICPSR_38925/TermsOfUse.html',
#  'ICPSR_38925-V1/ICPSR_38925/DS0004/',
#  'ICPSR_38925-V1/ICPSR_38925/DS0004/38925-0004-Documentation-readme_gzip.txt',
#  'ICPSR_38925-V1/ICPSR_38925/DS0004/38925-0004-Data.tsv',
#  'ICPSR_38925-V1/ICPSR_38925/DS0004/38925-0004-Codebook-ICPSR.pdf',
#  'ICPSR_38925-V1/ICPSR_38925/DS0005/',
#  'ICPSR_38925-V1/ICPSR_38925/DS0005/38925-0005-Documentation-readme_gzip.txt',
#  'ICPSR_38925-V1/ICPSR_38925/DS0005/38925-0005-Data.tsv',
#  'ICPSR_38925-V1/ICPSR_38925/DS0005/38925-0005-Codebook-ICPSR.pdf',
#  'ICPSR_38925-V1/ICPSR_38925/DS0006/',
#  'ICPSR_38925-V1/ICPSR_38925/DS0006/38925-0006-Codebook-ICPSR.pdf',
#  'ICPSR_38925-V1/ICPSR_38925/DS0006/38925-0006-Documentation-readme_gzip.txt',
#  'ICPSR_38925-V1/ICPSR_38925/DS0006/38925-0006-Data.tsv']

# %%
# Look up column names and data types
incident_schema = pl.read_parquet_schema(DS0003)
incident_schema
# Out:
# {'V40261': String,
#  'ALLOFNS-ALL OFFENSE CODES FOR THE INCIDENT': String,
#  'BH005-DATE ORI WAS ADDED': Datetime(time_unit='us', time_zone=None),
#  'BH006-DATE ORI WENT NIBRS': Datetime(time_unit='us', time_zone=None),
#  'BH007-CITY NAME': String,
#  'BH008-STATE ABBREVIATION': String,
#  'BH009-POPULATION GROUP': String,
#  'BH010-COUNTRY DIVISION': String,
#  'BH011-COUNTRY REGION': String,
#  'BH012-AGENCY INDICATOR': String,
#  'BH013-CORE CITY': String,
#  'BH014-COVERED BY ORI': String,
#  'BH015-FBI FIELD OFFICE': Int32,
#  'BH016-JUDICIAL DISTRICT': String,
#  'BH017-AGENCY NIBRS FLAG': String,
#  'BH018-AGENCY INACTIVE DATE': Datetime(time_unit='us', time_zone=None),
#  'BH019-CURRENT POPULATION 1': Int32,
#  'BH020-UCR COUNTY CODE 1': Int32,
#  'BH021-MSA CODE 1': Int32,
#  'BH022-LAST POPULATION 1': Int32,
#  'BH023-CURRENT POPULATION 2': Int32,
#  'BH024-UCR COUNTY CODE 2': Int32,
#  'BH025-MSA CODE 2': Int32,
#  'BH026-LAST POPULATION 2': Int32,
#  'BH027-CURRENT POPULATION 3': Int32,
#  'BH028-UCR COUNTY CODE 3': Int32,
#  'BH029-MSA CODE 3': Int32,
#  'BH030-LAST POPULATION 3': Int32,
#  'BH031-CURRENT POPULATION 4': Int32,
#  'BH032-UCR COUNTY CODE 4': Int32,
#  'BH033-MSA CODE 4': Int32,
#  'BH034-LAST POPULATION 4': Int32,
#  'BH035-CURRENT POPULATION 5': Int32,
#  'BH036-UCR COUNTY CODE 5': Int32,
#  'BH037-MSA CODE 5': Int32,
#  'BH038-LAST POPULATION 5': Int32,
#  'BH039-01-06-12 INDICATOR': Int32,
#  'BH040-NUMBER OF MONTHS REPORTED': Int32,
#  'BH041-MASTER FILE YEAR': Int32,
#  'BH042-AGENCY ACTIVITY INDICATORS JANUARY (See Codebook)': String,
#  'BH043-AGENCY ACTIVITY INDICATORS FEBRUARY (See Codebook)': String,
#  'BH044-AGENCY ACTIVITY INDICATORS MARCH (See Codebook)': String,
#  'BH045-AGENCY ACTIVITY INDICATORS APRIL (See Codebook)': String,
#  'BH046-AGENCY ACTIVITY INDICATORS MAY (See Codebook)': String,
#  'BH047-AGENCY ACTIVITY INDICATORS JUNE (See Codebook)': String,
#  'BH048-AGENCY ACTIVITY INDICATORS JULY (See Codebook)': String,
#  'BH049-AGENCY ACTIVITY INDICATORS AUGUST (See Codebook)': String,
#  'BH050-AGENCY ACTIVITY INDICATORS SEPTEMBER (See Codebook)': String,
#  'BH051-AGENCY ACTIVITY INDICATORS OCTOBER (See Codebook)': String,
#  'BH052-AGENCY ACTIVITY INDICATORS NOVEMBER (See Codebook)': String,
#  'BH053-AGENCY ACTIVITY INDICATORS DECEMBER (See Codebook)': String,
#  'BH054-FIPS COUNTY 1': Int32,
#  'BH055-FIPS COUNTY 2': Int32,
#  'BH056-FIPS COUNTY 3': Int32,
#  'BH057-FIPS COUNTY 4': Int32,
#  'BH058-FIPS COUNTY 5': Int32,
#  'BH059-DATE STATE BEGAN IBR FOR REPORTING LEOKA': Datetime(time_unit='us', time_zone=None),
#  'FIPS_STATE-FIPS STATE NUMERIC CODE': String,
#  'INCDATE-INCIDENT DATE': Datetime(time_unit='us', time_zone=None),
#  'INCNUM-INCIDENT NUMBER': String,
#  'ORI-ORIGINATING AGENCY IDENTIFIER': String,
#  'RECSADM-N ADMINISTRATIVE (01) RECORDS PER ORI-INCIDENT NUMBER': Int32,
#  'RECSARR-N ARRESTEE (06) RECORDS PER ORI-INCIDENT NUMBER': Int32,
#  'RECSBH-N BATCH HEADER RECORDS PER ORI-INCIDENT NUMBER': Int32,
#  'RECSOFR-N OFFENDER (05) RECORDS PER ORI-INCIDENT NUMBER': Int32,
#  'RECSOFS-N OFFENSE (02) RECORDS PER ORI-INCIDENT NUMBER': Int32,
#  'RECSPRP-N PROPERTY (03) RECORDS PER ORI-INCIDENT NUMBER': Int32,
#  'RECSVIC-N VICTIM (04) RECORDS PER ORI-INCIDENT NUMBER': Int32,
#  'SEGMENT-SEGMENT LEVEL': String,
#  'STATE-NUMERIC STATE CODE': String,
#  'V1006-REPORT DATE INDICATOR': String,
#  'V1007-INCIDENT DATE HOUR': Int32,
#  'V1008-TOTAL OFFENSE SEGMENTS': Int32,
#  'V1009-TOTAL VICTIM SEGMENTS': Int32,
#  'V1010-TOTAL OFFENDER SEGMENTS': Int32,
#  'V1011-TOTAL ARRESTEE SEGMENTS': Int32,
#  'V1012-CITY SUBMISSION': String,
#  'V1013-CLEARED EXCEPTIONALLY': String,
#  'V1014-EXCEPTIONAL CLEARANCE DATE': Datetime(time_unit='us', time_zone=None),
#  'V1016-CARGO THEFT': String,
#  'V20061-UCR OFFENSE CODE - 1': Int32,
#  'V20062-UCR OFFENSE CODE - 2': Int32,
#  'V20063-UCR OFFENSE CODE - 3': Int32,
#  'V20071-OFFENSE ATTEMPTED / COMPLETED - 1': Int32,
#  'V20072-OFFENSE ATTEMPTED / COMPLETED - 2': Int32,
#  'V20073-OFFENSE ATTEMPTED / COMPLETED - 3': Int32,
#  'V20081-OFFENDER(S) SUSPECTED OF USING 1 - 1': Int32,
#  'V20082-OFFENDER(S) SUSPECTED OF USING 1 - 2': Int32,
#  'V20083-OFFENDER(S) SUSPECTED OF USING 1 - 3': Int32,
#  'V20091-OFFENDER(S) SUSPECTED OF USING 2 - 1': Int32,
#  'V20092-OFFENDER(S) SUSPECTED OF USING 2 - 2': Int32,
#  'V20093-OFFENDER(S) SUSPECTED OF USING 2 - 3': Int32,
#  'V20101-OFFENDER(S) SUSPECTED OF USING 3 - 1': Int32,
#  'V20102-OFFENDER(S) SUSPECTED OF USING 3 - 2': Int32,
#  'V20103-OFFENDER(S) SUSPECTED OF USING 3 - 3': Int32,
#  'V20111-LOCATION TYPE - 1': Int32,
#  'V20112-LOCATION TYPE - 2': Int32,
#  'V20113-LOCATION TYPE - 3': Int32,
#  'V20121-NUMBER OF PREMISES ENTERED - 1': Int32,
#  'V20122-NUMBER OF PREMISES ENTERED - 2': Int32,
#  'V20123-NUMBER OF PREMISES ENTERED - 3': Int32,
#  'V20131-METHOD OF ENTRY - 1': Int32,
#  'V20132-METHOD OF ENTRY - 2': Int32,
#  'V20133-METHOD OF ENTRY - 3': Int32,
#  'V20141-TYPE CRIMINAL ACTIVITY/GANG INFO 1 - 1': String,
#  'V20142-TYPE CRIMINAL ACTIVITY/GANG INFO 1 - 2': Int32,
#  'V20143-TYPE CRIMINAL ACTIVITY/GANG INFO 1 - 3': Int32,
#  'V20151-TYPE CRIMINAL ACTIVITY/GANG INFO 2 - 1': Int32,
#  'V20152-TYPE CRIMINAL ACTIVITY/GANG INFO 2 - 2': Int32,
#  'V20153-TYPE CRIMINAL ACTIVITY/GANG INFO 2 - 3': Int32,
#  'V20161-TYPE CRIMINAL ACTIVITY/GANG INFO 3 - 1': Int32,
#  'V20162-TYPE CRIMINAL ACTIVITY/GANG INFO 3 - 2': Int32,
#  'V20163-TYPE CRIMINAL ACTIVITY/GANG INFO 3 - 3': Int32,
#  'V20171-WEAPON / FORCE 1 - 1': String,
#  'V20172-WEAPON / FORCE 1 - 2': String,
#  'V20173-WEAPON / FORCE 1 - 3': String,
#  'V20181-WEAPON / FORCE 2 - 1': String,
#  'V20182-WEAPON / FORCE 2 - 2': String,
#  'V20183-WEAPON / FORCE 2 - 3': String,
#  'V20191-WEAPON / FORCE 3 - 1': String,
#  'V20192-WEAPON / FORCE 3 - 2': String,
#  'V20193-WEAPON / FORCE 3 - 3': String,
#  'V20201-BIAS MOTIVATION 1 - 1': Int32,
#  'V20202-BIAS MOTIVATION 1 - 2': Int32,
#  'V20203-BIAS MOTIVATION 1 - 3': Int32,
#  'V2020B1-BIAS MOTIVATION 2 - 1': Int32,
#  'V2020B2-BIAS MOTIVATION 2 - 2': Int32,
#  'V2020B3-BIAS MOTIVATION 2 - 3': Int32,
#  'V2020C1-BIAS MOTIVATION 3 - 1': Int32,
#  'V2020C2-BIAS MOTIVATION 3 - 2': Int32,
#  'V2020C3-BIAS MOTIVATION 3 - 3': Int32,
#  'V2020D1-BIAS MOTIVATION 4 - 1': Int32,
#  'V2020D2-BIAS MOTIVATION 4 - 2': Int32,
#  'V2020D3-BIAS MOTIVATION 4 - 3': Int32,
#  'V2020E1-BIAS MOTIVATION 5 - 1': Int32,
#  'V2020E2-BIAS MOTIVATION 5 - 2': Int32,
#  'V2020E3-BIAS MOTIVATION 5 - 3': Int32,
#  'V30061-TYPE PROPERTY LOSS - 1': String,
#  'V30062-TYPE PROPERTY LOSS - 2': String,
#  'V30063-TYPE PROPERTY LOSS - 3': String,
#  'V30071-PROPERTY DESCRIPTION - 1': String,
#  'V30072-PROPERTY DESCRIPTION - 2': Int32,
#  'V30073-PROPERTY DESCRIPTION - 3': Int32,
#  'V30081-VALUE OF PROPERTY - 1': Int32,
#  'V30082-VALUE OF PROPERTY - 2': Int32,
#  'V30083-VALUE OF PROPERTY - 3': Int32,
#  'V30091-DATE RECOVERED - 1': Datetime(time_unit='us', time_zone=None),
#  'V30092-DATE RECOVERED - 2': Datetime(time_unit='us', time_zone=None),
#  'V30093-DATE RECOVERED - 3': Datetime(time_unit='us', time_zone=None),
#  'V30101-NUMBER OF STOLEN MOTOR VEHICLES - 1': Int32,
#  'V30102-NUMBER OF STOLEN MOTOR VEHICLES - 2': Int32,
#  'V30103-NUMBER OF STOLEN MOTOR VEHICLES - 3': Int32,
#  'V30111-NUMBER OF RECOVERED MOTOR VEHICLES - 1': Int32,
#  'V30112-NUMBER OF RECOVERED MOTOR VEHICLES - 2': Int32,
#  'V30113-NUMBER OF RECOVERED MOTOR VEHICLES - 3': Int32,
#  'V30121-SUSPECTED DRUG TYPE 1 - 1': String,
#  'V30122-SUSPECTED DRUG TYPE 1 - 2': String,
#  'V30123-SUSPECTED DRUG TYPE 1 - 3': String,
#  'V30131-ESTIMATED QUANTITY 1 - 1': Int32,
#  'V30132-ESTIMATED QUANTITY 1 - 2': Int32,
#  'V30133-ESTIMATED QUANTITY 1 - 3': Int32,
#  'V30141-ESTIMATED QTY 1 1/1000TH - 1': Int32,
#  'V30142-ESTIMATED QTY 1 1/1000TH - 2': Int32,
#  'V30143-ESTIMATED QTY 1 1/1000TH - 3': Int32,
#  'V30151-TYPE MEASUREMENT 1 - 1': String,
#  'V30152-TYPE MEASUREMENT 1 - 2': String,
#  'V30153-TYPE MEASUREMENT 1 - 3': String,
#  'V30161-SUSPECTED DRUG TYPE 2 - 1': String,
#  'V30162-SUSPECTED DRUG TYPE 2 - 2': String,
#  'V30163-SUSPECTED DRUG TYPE 2 - 3': String,
#  'V30171-ESTIMATED QUANTITY 2 - 1': Int32,
#  'V30172-ESTIMATED QUANTITY 2 - 2': Int32,
#  'V30173-ESTIMATED QUANTITY 2 - 3': Int32,
#  'V30181-ESTIMATED QTY 2 1/1000TH - 1': Int32,
#  'V30182-ESTIMATED QTY 2 1/1000TH - 2': Int32,
#  'V30183-ESTIMATED QTY 2 1/1000TH - 3': Int32,
#  'V30191-TYPE MEASUREMENT 2 - 1': String,
#  'V30192-TYPE MEASUREMENT 2 - 2': String,
#  'V30193-TYPE MEASUREMENT 2 - 3': String,
#  'V30201-SUSPECTED DRUG TYPE 3 - 1': String,
#  'V30202-SUSPECTED DRUG TYPE 3 - 2': String,
#  'V30203-SUSPECTED DRUG TYPE 3 - 3': String,
#  'V30211-ESTIMATED QUANTITY 3 - 1': Int32,
#  'V30212-ESTIMATED QUANTITY 3 - 2': Int32,
#  'V30213-ESTIMATED QUANTITY 3 - 3': Int32,
#  'V30221-ESTIMATED QTY 3 1/1000TH - 1': Int32,
#  'V30222-ESTIMATED QTY 3 1/1000TH - 2': Int32,
#  'V30223-ESTIMATED QTY 3 1/1000TH - 3': Int32,
#  'V30231-TYPE MEASUREMENT 3 - 1': String,
#  'V30232-TYPE MEASUREMENT 3 - 2': String,
#  'V30233-TYPE MEASUREMENT 3 - 3': String,
#  'V40061-VICTIM SEQUENCE NUMBER - 1': Int32,
#  'V40062-VICTIM SEQUENCE NUMBER - 2': Int32,
#  'V40063-VICTIM SEQUENCE NUMBER - 3': Int32,
#  'V40071-UCR OFFENSE CODE 1-1': Int32,
#  'V40072-UCR OFFENSE CODE 1-2': Int32,
#  'V40073-UCR OFFENSE CODE 1-3': Int32,
#  'V40081-UCR OFFENSE CODE 2-1': Int32,
#  'V40082-UCR OFFENSE CODE 2-2': Int32,
#  'V40083-UCR OFFENSE CODE 2-3': Int32,
#  'V40091-UCR OFFENSE CODE 3-1': Int32,
#  'V40092-UCR OFFENSE CODE 3-2': Int32,
#  'V40093-UCR OFFENSE CODE 3-3': Int32,
#  'V40101-UCR OFFENSE CODE 4-1': Int32,
#  'V40102-UCR OFFENSE CODE 4-2': Int32,
#  'V40103-UCR OFFENSE CODE 4-3': Int32,
#  'V40111-UCR OFFENSE CODE 5-1': Int32,
#  'V40112-UCR OFFENSE CODE 5-2': Int32,
#  'V40113-UCR OFFENSE CODE 5-3': Int32,
#  'V40121-UCR OFFENSE CODE 6-1': Int32,
#  'V40122-UCR OFFENSE CODE 6-2': Int32,
#  'V40123-UCR OFFENSE CODE 6-3': Int32,
#  'V40131-UCR OFFENSE CODE 7-1': Int32,
#  'V40132-UCR OFFENSE CODE 7-2': Int32,
#  'V40133-UCR OFFENSE CODE 7-3': Int32,
#  'V40141-UCR OFFENSE CODE 8-1': Int32,
#  'V40142-UCR OFFENSE CODE 8-2': Int32,
#  'V40143-UCR OFFENSE CODE 8-3': Int32,
#  'V40151-UCR OFFENSE CODE 9-1': Int32,
#  'V40152-UCR OFFENSE CODE 9-2': Int32,
#  'V40153-UCR OFFENSE CODE 9-3': Int32,
#  'V40161-UCR OFFENSE CODE 10-1': Int32,
#  'V40162-UCR OFFENSE CODE 10-2': Int32,
#  'V40163-UCR OFFENSE CODE 10-3': Int32,
#  'V40171-TYPE OF VICTIM-1': String,
#  'V40172-TYPE OF VICTIM-2': String,
#  'V40173-TYPE OF VICTIM-3': String,
#  'V4017A1-TYPE OF ACTIVITY (OFFICER)-1': String,
#  'V4017A2-TYPE OF ACTIVITY (OFFICER)-2': String,
#  'V4017A3-TYPE OF ACTIVITY (OFFICER)-3': String,
#  'V4017B1-ASSIGNMENT TYPE (OFFICER)-1': String,
#  'V4017B2-ASSIGNMENT TYPE (OFFICER)-2': String,
#  'V4017B3-ASSIGNMENT TYPE (OFFICER)-3': String,
#  'V4017C1-ORI OTHER JURISDICTION (OFFICER)-1': String,
#  'V4017C2-ORI OTHER JURISDICTION (OFFICER)-2': String,
#  'V4017C3-ORI OTHER JURISDICTION (OFFICER)-3': String,
#  'V40181-AGE OF VICTIM-1': String,
#  'V40182-AGE OF VICTIM-2': String,
#  'V40183-AGE OF VICTIM-3': String,
#  'V40191-SEX OF VICTIM-1': String,
#  'V40192-SEX OF VICTIM-2': String,
#  'V40193-SEX OF VICTIM-3': String,
#  'V40201-RACE OF VICTIM-1': String,
#  'V40202-RACE OF VICTIM-2': String,
#  'V40203-RACE OF VICTIM-3': String,
#  'V40211-ETHNICITY OF VICTIM-1': String,
#  'V40212-ETHNICITY OF VICTIM-2': String,
#  'V40213-ETHNICITY OF VICTIM-3': String,
#  'V40221-RESIDENT STATUS OF VICTIM-1': String,
#  'V40222-RESIDENT STATUS OF VICTIM-2': String,
#  'V40223-RESIDENT STATUS OF VICTIM-3': String,
#  'V40231-AGG ASLT/HOMICIDE CIRCUMSTANCE 1-1': String,
#  'V40232-AGG ASLT/HOMICIDE CIRCUMSTANCE 1-2': String,
#  'V40233-AGG ASLT/HOMICIDE CIRCUMSTANCE 1-3': String,
#  'V40241-AGG ASLT/HOMICIDE CIRCUMSTANCE 2-1': String,
#  'V40242-AGG ASLT/HOMICIDE CIRCUMSTANCE 2-2': String,
#  'V40243-AGG ASLT/HOMICIDE CIRCUMSTANCE 2-3': String,
#  'V40251-ADDITIONAL JUSTIFIABLE HOMICIDE CIRCUMSTANCES-1': String,
#  'V40252-ADDITIONAL JUSTIFIABLE HOMICIDE CIRCUMSTANCES-2': String,
#  'V40253-ADDITIONAL JUSTIFIABLE HOMICIDE CIRCUMSTANCES-3': String,
#  'V40262-INJURY 1-2': String,
#  'V40263-INJURY 1-3': String,
#  'V40271-INJURY 2-1': String,
#  'V40272-INJURY 2-2': String,
#  'V40273-INJURY 2-3': String,
#  'V40281-INJURY 3-1': String,
#  'V40282-INJURY 3-2': String,
#  'V40283-INJURY 3-3': String,
#  'V40291-INJURY 4-1': String,
#  'V40292-INJURY 4-2': String,
#  'V40293-INJURY 4-3': String,
#  'V40301-INJURY 5-1': String,
#  'V40302-INJURY 5-2': String,
#  'V40303-INJURY 5-3': String,
#  'V40311-OFFENDER NUMBER 1-1': Int32,
#  'V40312-OFFENDER NUMBER 1-2': Int32,
#  'V40313-OFFENDER NUMBER 1-3': Int32,
#  'V40321-RELATIONSHIP VIC TO OFF 1-1': String,
#  'V40322-RELATIONSHIP VIC TO OFF 1-2': String,
#  'V40323-RELATIONSHIP VIC TO OFF 1-3': String,
#  'V40331-OFFENDER NUMBER 2-1': Int32,
#  'V40332-OFFENDER NUMBER 2-2': Int32,
#  'V40333-OFFENDER NUMBER 2-3': Int32,
#  'V40341-RELATIONSHIP VIC TO OFF 2-1': String,
#  'V40342-RELATIONSHIP VIC TO OFF 2-2': String,
#  'V40343-RELATIONSHIP VIC TO OFF 2-3': String,
#  'V40351-OFFENDER NUMBER 3-1': Int32,
#  'V40352-OFFENDER NUMBER 3-2': Int32,
#  'V40353-OFFENDER NUMBER 3-3': Int32,
#  'V40361-RELATIONSHIP VIC TO OFF 3-1': String,
#  'V40362-RELATIONSHIP VIC TO OFF 3-2': String,
#  'V40363-RELATIONSHIP VIC TO OFF 3-3': String,
#  'V40371-OFFENDER NUMBER 4-1': Int32,
#  'V40372-OFFENDER NUMBER 4-2': Int32,
#  'V40373-OFFENDER NUMBER 4-3': Int32,
#  'V40381-RELATIONSHIP VIC TO OFF 4-1': String,
#  'V40382-RELATIONSHIP VIC TO OFF 4-2': String,
#  'V40383-RELATIONSHIP VIC TO OFF 4-3': String,
#  'V40391-OFFENDER NUMBER 5-1': Int32,
#  'V40392-OFFENDER NUMBER 5-2': Int32,
#  'V40393-OFFENDER NUMBER 5-3': Int32,
#  'V40401-RELATIONSHIP VIC TO OFF 5-1': String,
#  'V40402-RELATIONSHIP VIC TO OFF 5-2': String,
#  'V40403-RELATIONSHIP VIC TO OFF 5-3': String,
#  'V40411-OFFENDER NUMBER 6-1': Int32,
#  'V40412-OFFENDER NUMBER 6-2': Int32,
#  'V40413-OFFENDER NUMBER 6-3': Int32,
#  'V40421-RELATIONSHIP VIC TO OFF 6-1': String,
#  'V40422-RELATIONSHIP VIC TO OFF 6-2': String,
#  'V40423-RELATIONSHIP VIC TO OFF 6-3': String,
#  'V40431-OFFENDER NUMBER 7-1': Int32,
#  'V40432-OFFENDER NUMBER 7-2': Int32,
#  'V40433-OFFENDER NUMBER 7-3': Int32,
#  'V40441-RELATIONSHIP VIC TO OFF 7-1': String,
#  'V40442-RELATIONSHIP VIC TO OFF 7-2': String,
#  'V40443-RELATIONSHIP VIC TO OFF 7-3': String,
#  'V40451-OFFENDER NUMBER 8-1': Int32,
#  'V40452-OFFENDER NUMBER 8-2': Int32,
#  'V40453-OFFENDER NUMBER 8-3': Int32,
#  'V40461-RELATIONSHIP VIC TO OFF 8-1': String,
#  'V40462-RELATIONSHIP VIC TO OFF 8-2': String,
#  'V40463-RELATIONSHIP VIC TO OFF 8-3': String,
#  'V40471-OFFENDER NUMBER 9-1': Int32,
#  'V40472-OFFENDER NUMBER 9-2': Int32,
#  'V40473-OFFENDER NUMBER 9-3': Int32,
#  'V40481-RELATIONSHIP VIC TO OFF 9-1': String,
#  'V40482-RELATIONSHIP VIC TO OFF 9-2': String,
#  'V40483-RELATIONSHIP VIC TO OFF 9-3': String,
#  'V40491-OFFENDER NUMBER 10-1': Int32,
#  'V40492-OFFENDER NUMBER 10-2': Int32,
#  'V40493-OFFENDER NUMBER 10-3': Int32,
#  'V40501-RELATIONSHIP VIC TO OFF 10-1': String,
#  'V40502-RELATIONSHIP VIC TO OFF 10-2': String,
#  'V40503-RELATIONSHIP VIC TO OFF 10-3': String,
#  'V50061-OFFENDER SEQUENCE NUMBER - 1': Int32,
#  'V50062-OFFENDER SEQUENCE NUMBER - 2': Int32,
#  'V50063-OFFENDER SEQUENCE NUMBER - 3': Int32,
#  'V50071-AGE OF OFFENDER - 1': Int32,
#  'V50072-AGE OF OFFENDER - 2': Int32,
#  'V50073-AGE OF OFFENDER - 3': Int32,
#  'V50081-SEX OF OFFENDER - 1': Int32,
#  'V50082-SEX OF OFFENDER - 2': Int32,
#  'V50083-SEX OF OFFENDER - 3': Int32,
#  'V50091-RACE OF OFFENDER - 1': String,
#  'V50092-RACE OF OFFENDER - 2': String,
#  'V50093-RACE OF OFFENDER - 3': String,
#  'V50111-ETHNICITY OF OFFENDER - 1': Int32,
#  'V50112-ETHNICITY OF OFFENDER - 2': Int32,
#  'V50113-ETHNICITY OF OFFENDER - 3': Int32,
#  'V60061-ARRESTEE SEQUENCE NUMBER - 1': Int32,
#  'V60062-ARRESTEE SEQUENCE NUMBER - 2': Int32,
#  'V60063-ARRESTEE SEQUENCE NUMBER - 3': Int32,
#  'V60071-ARREST TRANSACTION NUMBER - 1': String,
#  'V60072-ARREST TRANSACTION NUMBER - 2': String,
#  'V60073-ARREST TRANSACTION NUMBER - 3': String,
#  'V60081-ARREST DATE - 1': Datetime(time_unit='us', time_zone=None),
#  'V60082-ARREST DATE - 2': Datetime(time_unit='us', time_zone=None),
#  'V60083-ARREST DATE - 3': Datetime(time_unit='us', time_zone=None),
#  'V60091-TYPE OF ARREST - 1': Int32,
#  'V60092-TYPE OF ARREST - 2': Int32,
#  'V60093-TYPE OF ARREST - 3': Int32,
#  'V60101-MULTIPLE ARRESTEE SEGMENTS INDICATOR - 1': String,
#  'V60102-MULTIPLE ARRESTEE SEGMENTS INDICATOR - 2': String,
#  'V60103-MULTIPLE ARRESTEE SEGMENTS INDICATOR - 3': String,
#  'V60111-UCR ARREST OFFENSE CODE - 1': Int32,
#  'V60112-UCR ARREST OFFENSE CODE - 2': Int32,
#  'V60113-UCR ARREST OFFENSE CODE - 3': Int32,
#  'V60121-ARRESTEE ARMED WITH 1 - 1': String,
#  'V60122-ARRESTEE ARMED WITH 1 - 2': String,
#  'V60123-ARRESTEE ARMED WITH 1 - 3': String,
#  'V60131-ARRESTEE ARMED WITH 2 - 1': String,
#  'V60132-ARRESTEE ARMED WITH 2 - 2': String,
#  'V60133-ARRESTEE ARMED WITH 2 - 3': String,
#  'V60141-AGE OF ARRESTEE - 1': Int32,
#  'V60142-AGE OF ARRESTEE - 2': Int32,
#  'V60143-AGE OF ARRESTEE - 3': Int32,
#  'V60151-SEX OF ARRESTEE - 1': Int32,
#  'V60152-SEX OF ARRESTEE - 2': Int32,
#  'V60153-SEX OF ARRESTEE - 3': Int32,
#  'V60161-RACE OF ARRESTEE - 1': String,
#  'V60162-RACE OF ARRESTEE - 2': String,
#  'V60163-RACE OF ARRESTEE - 3': String,
#  'V60171-ETHNICITY OF ARRESTEE - 1': String,
#  'V60172-ETHNICITY OF ARRESTEE - 2': String,
#  'V60173-ETHNICITY OF ARRESTEE - 3': String,
#  'V60181-RESIDENT STATUS OF ARRESTEE - 1': String,
#  'V60182-RESIDENT STATUS OF ARRESTEE - 2': String,
#  'V60183-RESIDENT STATUS OF ARRESTEE - 3': String,
#  'V60191-DISPOSITION OF ARRESTEE UNDER 18 - 1': Int32,
#  'V60192-DISPOSITION OF ARRESTEE UNDER 18 - 2': Int32,
#  'V60193-DISPOSITION OF ARRESTEE UNDER 18 - 3': Int32}

# %%
# Columns with important data
important_data = [
    'STATE-NUMERIC STATE CODE', 'INCNUM-INCIDENT NUMBER', 'INCDATE-INCIDENT DATE',
    'BH007-CITY NAME', 'BH008-STATE ABBREVIATION', 'V1008-TOTAL OFFENSE SEGMENTS',
    'V1009-TOTAL VICTIM SEGMENTS', 'V1010-TOTAL OFFENDER SEGMENTS', 'V1011-TOTAL ARRESTEE SEGMENTS',
    'V20061-UCR OFFENSE CODE - 1', 'V20111-LOCATION TYPE - 1', 'V20141-TYPE CRIMINAL ACTIVITY/GANG INFO 1 - 1',
    'V20171-WEAPON / FORCE 1 - 1', 'V20201-BIAS MOTIVATION 1 - 1', 'V30121-SUSPECTED DRUG TYPE 1 - 1',
    'V40171-TYPE OF VICTIM-1', 'V40181-AGE OF VICTIM-1', 'V40191-SEX OF VICTIM-1',
    'V40201-RACE OF VICTIM-1', 'V40211-ETHNICITY OF VICTIM-1', 'V40221-RESIDENT STATUS OF VICTIM-1',
    'V40321-RELATIONSHIP VIC TO OFF 1-1', 'V50071-AGE OF OFFENDER - 1', 'V50081-SEX OF OFFENDER - 1',
    'V50091-RACE OF OFFENDER - 1', 'V50111-ETHNICITY OF OFFENDER - 1', 'V60081-ARREST DATE - 1',
    'V60121-ARRESTEE ARMED WITH 1 - 1', 'V60141-AGE OF ARRESTEE - 1', 'V60151-SEX OF ARRESTEE - 1',
    'V60161-RACE OF ARRESTEE - 1', 'V60171-ETHNICITY OF ARRESTEE - 1', 'V60181-RESIDENT STATUS OF ARRESTEE - 1',
    'V60191-DISPOSITION OF ARRESTEE UNDER 18 - 1'
]

# %%
# Read in city names
cities = pl.scan_parquet(
    DS0003,
).select(
    'BH007-CITY NAME'
).collect()

# Inspect unique names
unique_names = cities['BH007-CITY NAME'].str.to_lowercase().unique()
unique_names
# Out:
# shape: (5_989,)
# Series: 'BH007-CITY NAME' [str]
# [
# 	"sugar hill"
# 	"lake providence"
# 	"fultondale"
# 	"bison"
# 	"roseland"
# 	…
# 	"saint francisville"
# 	"oquawka"
# 	"gordonsville"
# 	"cashion"
# 	"robinson"
# ]

# %%
# Filter city names containing 'north', 'south', 'east', or 'west'
regions = ['north', 'south', 'east', 'west']
filtered_city_names = unique_names.filter(
    unique_names.str.contains('|'.join(regions))
)
filtered_city_names
# Out:
# shape: (261,)
# Series: 'BH007-CITY NAME' [str]
# [
# 	"south fulton"
# 	"westborough"
# 	"south berwick"
# 	"west berlin"
# 	"west dover"
# 	…
# 	"key west"
# 	"midwest city"
# 	"northlake"
# 	"west plains"
# 	"north ridgeville"
# ]

# %%
# Filter city names with 'boston', 'chicago', and 'nashville'
targets = ['boston', 'chicago', 'nashville']
targeted_city_names = unique_names.filter(
    unique_names.str.contains('|'.join(targets))
)
targeted_city_names
# Out:
# shape: (10,)
# Series: 'BH007-CITY NAME' [str]
# [
# 	"boston"
# 	"west chicago"
# 	"south boston"
# 	"nashville"
# 	"chicago"
# 	"east chicago"
# 	"chicago ridge"
# 	"chicago heights"
# 	"new boston"
# 	"south chicago heights"
# ]

# %% [markdown]
# #### **Task:** Analyze the cities vs. all of their related names
# - **New Boston** is in New Hampshire.
# - **East Chicago** is in Indiana.
# - There's only one occurrence of **Nashville**.
